# %%
from threading import Thread
from multiprocessing import Process
import functions as fu
import pandas as pd
import json

with open('broken_original/2019-11-19T19_34_02Z_oi-contabilizei_data.json', 'r') as f:
    data = json.load(f)

df = pd.DataFrame(data)
pd.set_option('display.max_colwidth', -1)
pd.set_option('display.max_columns', 999)

del df['qualificacao']

df.head(30)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                          qualificacao
# 00000000000191                    {'dados': {'atendeCliente': False, 'atividadePrincipal': {'codigo': '6422100', 'descricao': 'Bancos múltiplos com carteira comercial'}, 'atividadeSecundaria': {'0': {'codigo': '6499999', 'descricao': 'Outras atividades de serviços financeiros não especificadas anteriormente'}}, 'cnpj': '00000000000191', 'motivosRecusa': {'0': 'CIDADE_NAO_ATENDIDA'}, 'municipio': 'BRASILIA', 'nomeFantasia': 'DIRECAO GERAL', 'razaoSocial': 'BANCO DO BRASIL SA', 'situacaoCadastral': 'ATIVA', 'socios': {'0': {'codigoQualificacao': '10', 'nome': 'MARCIO HAMILTON FERREIRA'}, '1': {'codigoQualificacao': '10', 'nome': 'NILSON MARTINIANO MOREIRA'}, '2': {'codigoQualificacao': '10', 'nome': 'WALTER MALIENI JUNIOR'}, '3': {'codigoQualificacao': '10', 'nome': 'ADRIANO MEIRA RICCI'}, '4': {'codigoQualificacao': '10', 'nome': 'CARLOS ALBERTO ARAUJO NETTO'}, '5': {'codigoQualificacao': '10', 'nome': 'ANTONIO MAURICIO MAURANO'}, '6': {'codigoQualificacao': '16', 'nome': 'MARCELO AUGUSTO DUTRA LABUTO'}, '7': {'codigoQualificacao': '10', 'nome': 'LEONARDO SILVA DE LOYOLA REIS'}, '8': {'codigoQualificacao': '10', 'nome': 'ROGERIO MAGNO PANCA'}, '9': {'codigoQualificacao': '10', 'nome': 'SIMAO LUIZ KOVALSKI'}, '10': {'codigoQualificacao': '10', 'nome': 'TARCISIO HUBNER'}, '11': {'codigoQualificacao': '10', 'nome': 'EDUARDO CESAR PASA'}, '12': {'codigoQualificacao': '10', 'nome': 'MARCIO LUIZ MORAL'}, '13': {'codigoQualificacao': '10', 'nome': 'JOSE EDUARDO MOREIRA BERGO'}, '14': {'codigoQualificacao': '10', 'nome': 'ALEXANDRE ALVES DE SOUZA'}, '15': {'codigoQualificacao': '10', 'nome': 'CICERO PRZENDSIUK'}, '16': {'codigoQualificacao': '10', 'nome': 'EDSON ROGERIO DA COSTA'}, '17': {'codigoQualificacao': '10', 'nome': 'FABIANO MACANHAN FONTES'}, '18': {'codigoQualificacao': '10', 'nome': 'FERNANDO FLORENCIO CAMPOS'}, '19': {'codigoQualificacao': '10', 'nome': 'GUSTAVO DE SOUZA FOSSE'}, '20': {'codigoQualificacao': '10', 'nome': 'MARCO TULIO DE OLIVEIRA MENDONCA'}, '21': {'codigoQualificacao': '10', 'nome': 'MARVIO MELO FREITAS'}, '22': {'codigoQualificacao': '10', 'nome': 'REINALDO KAZUFUMI YOKOYAMA'}, '23': {'codigoQualificacao': '10', 'nome': 'JOSE CAETANO DE ANDRADE MINCHILLO'}, '24': {'codigoQualificacao': '10', 'nome': 'CARLOS RENATO BONETTI'}, '25': {'codigoQualificacao': '10', 'nome': 'MARCO ANTONIO ASCOLI MASTROENI'}, '26': {'codigoQualificacao': '10', 'nome': 'JOSE EDUARDO PEREIRA FILHO'}, '27': {'codigoQualificacao': '10', 'nome': 'MARCO TULIO MORAES DA COSTA'}, '28': {'codigoQualificacao': '10', 'nome': 'JOAO PINTO RABELO JUNIOR'}, '29': {'codigoQualificacao': '10', 'nome': 'CARLOS HAMILTON VASCONCELOS ARAUJO'}, '30': {'codigoQualificacao': '10', 'nome': 'LUCINEIA POSSAR'}, '31': {'codigoQualificacao': '10', 'nome': 'JOSE RICARDO FAGONDE FORNI'}, '32': {'codigoQualificacao': '10', 'nome': 'MARCOS RENATO COLTRI'}, '33': {'codigoQualificacao': '10', 'nome': 'CARLA NESI'}, '34': {'codigoQualificacao': '10', 'nome': 'BERNARDO DE AZEVEDO SILVA ROTHE'}, '35': {'codigoQualificacao': '10', 'nome': 'ANTONIO GUSTAVO MATOS DO VALE'}}, 'uf': 'DF'}, 'empresaValida': True, 'qualificatedAt': {'date': 8, 'day': 5, 'hours': 1, 'minutes': 11, 'month': 10, 'seconds': 49, 'time': 1573175509290, 'timezoneOffset': 0, 'year': 119}, 'status': 'CNPJ_VALIDO'}
# 00000254000100                    {'dados': {'atendeCliente': True, 'atividadePrincipal': {'codigo': '8299799', 'descricao': 'OUTRAS ATIVIDADES DE SERVIÇOS PRESTADOS PRINCIPALMENTE ÀS EMPRESAS NÃO ESPECIFICADAS ANTERIORMENTE'}, 'atividadeSecundaria': {'0': {'codigo': '4520001', 'descricao': 'SERVIÇOS DE MANUTENÇÃO E REPARAÇÃO MECÂNICA DE VEÍCULOS AUTOMOTORES'}}, 'cnpj': '00000254000100', 'municipio': 'SAO PAULO', 'nomeFantasia': '', 'ramoAtividade': {'0': 'SERVICO'}, 'razaoSocial': 'CAR-REMA SERVICOS EM REPARACAO E REMOCAO DE VEICULOS LTDA.', 'situacaoCadastral': 'ATIVA', 'socios': {'0': {'codigoQualificacao': '49', 'cpfCnpj': '000***110078**', 'descricaoQualificacao': 'SÓCIO-ADMINISTRADOR', 'nome': 'LUIS CARLOS DA ROSA', 'tipoPessoa': 'FISICA'}, '1': {'codigoQualificacao': '49', 'cpfCnpj': '000***951098**', 'descricaoQualificacao': 'SÓCIO-ADMINISTRADOR', 'nome': 'MARCELO RAFAEL SCALA', 'tipoPessoa': 'FISICA'}}, 'uf': 'SP'}, 'empresaValida': True, 'qualificatedAt': {'date': 19, 'day': 2, 'hours': 19, 'minutes': 5, 'month': 10, 'seconds': 3, 'time': 1574190303084, 'timezoneOffset': 0, 'year': 119}, 'status': 'CNPJ_VALIDO'}
# 0000406F3E59800B88131976C42F9F10  NaN
# 00007322000162                    {'dados': {'atendeCliente': True, 'atividadePrincipal': {'codigo': '4744099', 'descricao': 'COMÉRCIO VAREJISTA DE MATERIAIS DE CONSTRUÇÃO EM GERAL'}, 'atividadeSecundaria': {'0': {'codigo': '4744003', 'descricao': 'COMÉRCIO VAREJISTA DE MATERIAIS HIDRÁULICOS'}, '1': {'codigo': '4744002', 'descricao': 'COMÉRCIO VAREJISTA DE MADEIRA E ARTEFATOS'}, '2': {'codigo': '4742300', 'descricao': 'COMÉRCIO VAREJISTA DE MATERIAL ELÉTRICO'}}, 'cnpj': '00007322000162', 'municipio': 'SAO PAULO', 'nomeFantasia': '', 'ramoAtividade': {'0': 'COMERCIO'}, 'razaoSocial': 'ALFA SP COMERCIO DE MATERIAIS PARA CONSTRUCAO LTDA', 'situacaoCadastral': 'ATIVA', 'socios': {'0': {'codigoQualificacao': '49', 'cpfCnpj': '000***125328**', 'descricaoQualificacao': 'SÓCIO-ADMINISTRADOR', 'nome': 'FABIO EDUARDO MATARAZZO', 'tipoPessoa': 'FISICA'}, '1': {'codigoQualificacao': '49', 'cpfCnpj': '000***154728**', 'descricaoQualificacao': 'SÓCIO-ADMINISTRADOR', 'nome': 'LUIGI MATARAZZO', 'tipoPessoa': 'FISICA'}, '2': {'codigoQualificacao': '49', 'cpfCnpj': '000***444948**', 'descricaoQualificacao': 'SÓCIO-ADMINISTRADOR', 'nome': 'ROSANA CRISTINA FERRO MATARAZZO', 'tipoPessoa': 'FISICA'}}, 'uf': 'SP'}, 'empresaValida': True, 'qualificatedAt': {'date': 14, 'day': 1, 'hours': 13, 'minutes': 36, 'month': 9, 'seconds': 37, 'time': 1571060197443, 'timezoneOffset': 0, 'year': 119}, 'status': 'CNPJ_VALIDO'}
# 00007900000160                    {'dados': {'atendeCliente': False, 'atividadePrincipal': {'codigo': '4744005', 'descricao': 'Comércio varejista de materiais de construção não especificados anteriormente'}, 'atividadeSecundaria': {'0': {'codigo': '4930202', 'descricao': 'Transporte rodoviário de carga exceto produtos perigosos e mudanças intermunicipal interestadual e internacional'}}, 'cnpj': '00007900000160', 'motivosRecusa': {'0': 'CNAE 4930202  NÂO ATENDIDA'}, 'municipio': 'SAO PAULO', 'nomeFantasia': 'AQUARUM COMERCIO DE MATERIAIS PARA CONSTRUCOES LTDA', 'ramoAtividade': {'0': 'COMERCIO', '1': 'SERVICO'}, 'razaoSocial': 'AQUARUM COMERCIO DE MATERIAIS PARA CONSTRUCOES LTDA', 'situacaoCadastral': 'ATIVA', 'socios': {'0': {'codigoQualificacao': '49', 'nome': 'GILMAR JOSE DE OLIVEIRA'}, '1': {'codigoQualificacao': '49', 'nome': 'SUELI DE OLIVEIRA'}, '2': {'codigoQualificacao': '49', 'nome': 'GILSON JOSE DE OLIVEIRA'}}, 'uf': 'SP'}, 'empresaValida': True, 'qualificatedAt': {'date': 27, 'day': 2, 'hours': 21, 'minutes': 34, 'month': 7, 'seconds': 2, 'time': 1566941642011, 'timezoneOffset': 0, 'year': 119}, 'status': 'CNPJ_VALIDO'}
# 0000BBE117023BB2BF9B132A3D3314AE  NaN
# 0000D3C841BDC831DDEDA1890300B923  NaN
# 00012A587535720BD46C47691167D20A  NaN
# 0001476C86F1310F958C26E4D49F51B0  NaN
# 00014BDA8937B955EAD4764E7F7AC527  NaN
# 00014ED8091E76A30A4A20A18896B7F6  NaN
# 0001542DDB06AA7D60F6F21949F4F146  NaN
# 00015F461B9137D39A34628B2846C307  NaN
# ...
# 000269863BDC42AFD3C1F41E7853B174  NaN
# 00028DBF14F31BBAC756CF6565CB36EC  NaN
# 0002BA45A9DBC90D251541F0F8B37481  NaN
# 0002E091CC011A81CC5393B751A84FB8  NaN
# 0002FE421476533B5A9F444B39B05B80  NaN
